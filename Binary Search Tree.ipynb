# %%
class BST:
    def __init__(self, root):
        self.root = root
        self.left = None
        self.right = None
        
    def insert(self, value):
        if value < self.root:
            if self.left is None:
                self.left = BST(value)
            else:
                self.left.insert(value)
        else:
            if self.right is None:
                self.right = BST(value)
            else:
                self.right.insert(value)
    
    def search(self, value):
        if value == self.root:
            return f'{value} found'
        elif self.left is None and self.right is None:
            return f'{value} not found'
        elif value < self.root:
            if self.left is None:
                return f'{value} not found'
            else:
                return self.left.search(value)
        else:
            if self.right is None:
                return f'{value} not found'
            else:
                return self.right.search(value)
            
    def inorder(self):
        if self.left:
            self.left.inorder()
        print(self.root)
        if self.right:
            self.right.inorder()
        
    def preorder(self):
        print(self.root)
        if self.left:
            self.left.preorder()
        if self.right:
            self.right.preorder()
            
    def postorder(self):
        if self.left:
            self.left.preorder()
        if self.right:
            self.right.preorder()
        print(self.root)

# %%
class Node:
    def __init__(self, val):
        self.value = val
        self.left = None
        self.right = None
        
class BST:
    def __init__(self):
        self.root = None
    
    def insert(self, val, root=None):
        if root == None:
            root = self.root
        if self.root == None:
            self.root = Node(val)
        else:
            if val < root.value:
                if root.left is None:
                    root.left = Node(val)
                else:
                    self.insert(val, root.left)
            else:
                if root.right is None:
                    root.right = Node(val)
                else:
                    self.insert(val, root.right)
                    
    def search(self, val, root=bst.root):
        if val == root.value:
            return 'found'
        elif root.left is None and root.right is None:
            return 'not found'
        elif val < root.value:
            if root.left is None:
                return 'not found'
            else:
                return self.search(val, root.left)
        else:
            if root.right is None:
                return 'not found'
            else:
                return self.search(val, root.right)
        
    
    def display(self, root=bst.root):
        if root:
            self.display(root.left)
        if root:
            print(root.value)
        if root:
            self.display(root.right)
            
bst = BST()
from random import randint
arr = [randint(1, 10) for i in range(20)]
print(arr)
for i in arr:
    bst.insert(i)
    
bst.display()
bst.search(2)
# Out:
# [6, 8, 7, 2, 5, 4, 1, 2, 8, 6, 6, 1, 2, 7, 8, 10, 3, 1, 10, 9]
# 1
# 2
# 2
# 4
# 4
# 5
# 5
# 5
# 5
# 7
# 7
# 7
# 8
# 8
# 8
# 8
# 8
# 8
# 9
# 9
# 'found'

# %%
class Node:
    def __init__(self, val):
        self.value = val
        self.left = None
        self.right = None
        
class BST:
    def __init__(self):
        self.root = None
    
    def insert(self, val, root=None):
        if root is None:
            root = self.root
        if self.root is None:
            self.root = Node(val)
        else:
            if val < root.value:
                if root.left is None:
                    root.left = Node(val)
                else:
                    self.insert(val, root.left)
            else:
                if root.right is None:
                    root.right = Node(val)
                else:
                    self.insert(val, root.right)
    
    def search(self, val, root=bst.root):
        if root.value == val:
            return 'found'
        elif root.left is None and root.right is None:
            return 'not found'
        elif val < root.value:
            if root.left is None:
                return 'not found'
            else:
                return self.search(val, root.left)
        else:
            if root.right is None:
                return 'not found'
            else:
                return self.search(val, root.right)
            
    def display(self, root=bst.root):
        if root.left:
            self.display(root.left)
        print(root.value)
        if root.right:
            self.display(root.right)
            
bst = BST()
bst.insert(13)
bst.insert(4)
bst.insert(8)
bst.insert(5)
bst.insert(17)
bst.insert(9)
bst.display()
# Out:
# 1
# 2
# 2
# 3
# 4
# 4
# 4
# 4
# 5
# 6
# 6
# 7
# 7
# 7
# 7
# 8
# 9
# 9
# 9
# 10
